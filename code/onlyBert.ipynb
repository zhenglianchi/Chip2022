# %%
with open("res/infer_results.txt","r",encoding="utf-8") as f:
    res=f.read().splitlines()

filename=[]
data=[]
for item in res:
    filename.append(item.split("\t")[0].split("/")[-1])
    data.append(item.split("\t")[1])

# %%
import json
res=[]
for item in data:
    dataitem=json.loads(item)["ocr_info"]
    res.append(dataitem)

# %%
with open("train_data/fp/label_name.txt","r",encoding="utf-8") as f:
    label_list=f.read().splitlines()
key_name=[]
for item in label_list:
    first=item.split("_")[0]
    if first not in key_name:
        key_name.append(first)
del key_name[0]

key_eng=["GENDER","AGE","NAME","OCODE","OTYPE","IN","OUT","DAY","PC","PH","JY","OPEN","SK","FH","JS","XX","SKDW",
        "YBLX","HJ","ZC","JC","HY","ZL","SS","WSCL","XY","ZYYP","ZCYF","YBZL","CW","HL","GH","QT","YBTC","TC",
        "XJ","ZH","GRZF","QTZF","ZFY","ZFE"]
        
token2label={}
for a,b in zip(key_name,key_eng):
    token2label[a]=b

label2token={}
for key,value in token2label.items():
    label2token[value]=key

# %%
result=[]
for item in res:
    itemjson={}
    for i in item:
        if i["pred"]!="O" and i["pred"] not in itemjson.keys():
            itemjson[i["pred"]]=i["transcription"]
    result.append(itemjson)

# %%
from datasets import load_dataset
traindata=load_dataset("csv",data_files="datasets/TestB.csv")
mark=traindata["train"]
traindata=traindata["train"]
markdata={}
value={}
name="0055f88d65_20.jpg"
lastname=""
for item in mark:
    if item["图名"]!=name:
        markdata[lastname]=value
        value={}
        name=item["图名"]
    value[item["属性名"]]=item["正确值"]
    lastname=item["图名"]

markdata[mark[-1]["图名"]]=value

for key,value in markdata.items():
    if "入院日期" in value.keys():
        value["住院日期"]=value["入院日期"]
        value["入院时间"]=value["入院日期"]
    if "出院日期" in value.keys():
        value["出院时间"]=value["出院日期"]
    if "住院天数" in value.keys():
        value["住院日数"]=value["住院天数"]
        value["共住院"]=value["住院天数"]
    if "（小写）" in value.keys():
        value["￥"]=value["（小写）"]
    if "票据号码" in value.keys():
        value["No"]=value["票据号码"]
        value["NO"]=value["票据号码"]
    if "收款单位" in value.keys():
        value["收款单位（章）"]=value["收款单位"]
        value["收款单位（盖章）"]=value["收款单位"]
    if "收款人" in value.keys():
        value["收款人（章）"]=value["收款人"]
        value["收款人（盖章）"]=value["收款人"]
    if "（小写）" in value.keys():
        value["¥"]=value["（小写）"]
# Out:
# Using custom data configuration default-88a707933e1f1530
# Reusing dataset csv (D:\hugging-face\datasets\csv\default-88a707933e1f1530\0.0.0\51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
def compare(s1,s2):
    index=[]
    max=0
    data=""
    for l in s2:
        windows=len(list(l))
        for i in range(len(s1)-windows+1):
            num=0
            for j in range(windows):
                if s1[i+j]==l[j]:
                    num+=1
            score=num/windows
            if score>=max:
                index=[]
                index.append(i)
                index.append(i+windows-1)
                max=score
                data=l
        
    if max>=0.66:
        return index,data
    else:
        return -1,-1

# %%
l1=["收款单位","收款单位（章）","收款单位（盖章）","收款单位（签章）"]
l2=["收款人","收款人（章）","收款人（盖章）","收款人（签章）"]

# %%
import re
f=["：",":",",","，",".","·"]
res=result.copy()
for i in range(len(filename)):
    for j in markdata.keys():
        if j in filename[i] and j.split(".")[0]==filename[i].split(".")[0]:

            sk=""
            date=""
            for key,value in list(result[i].items()):
                first=key.split("_")[0]
                second=key.split("_")[1]
                if first=="SKDW" or first=="SK":
                    sk+=value
                #暂时对小写和大写忽略
                if first=="JS" or first=="HJ":
                    res[i][key]=res[i][key].replace("◆","")
                    res[i][key]=res[i][key].replace("?","")
                    continue

                if key=="XX_VALUE":
                    value=value.replace(" ","")
                    mo=r'[\u4e00-\u9fa5]{1,20}'
                    r=re.findall(mo,value)
                    if len(list(r))>0:
                        value=value.replace(r[0],"")
                        res[i]["XX_VALUE"]=value
                
                if key=="IN_KEY" or key=="IN_VALUE" or key=="OUT_KEY" or key=="OUT_VALUE" and len(value)>18:
                    date+=value
                    
                #如果有值的话忽略
                if second == "VALUE":
                    continue
                else:
                    if first+'_'+"VALUE" in result[i].keys():
                        continue
                    else:
                        index,z=compare(value,markdata[j].keys())
                        if index!=-1 and z!=-1:
                            temp=list(value)
                            if len(value)-1>index[1] and value[index[1]+1] in f:
                                res[i][first+"_"+"KEY"]="".join(temp[index[0]:index[1]+2])
                                res[i][first+"_"+"VALUE"]="".join(temp[index[1]+2:])
                            else:
                                res[i][first+"_"+"KEY"]="".join(temp[index[0]:index[1]+1])
                                res[i][first+"_"+"VALUE"]="".join(temp[index[1]+1:])
            
            index1,z1=compare(sk,l1)
            index2,z2=compare(sk,l2)
            temp=list(sk)
            if index1!=-1 and index2!=-1:
                if len(temp)-1>index1[1] and temp[index1[1]+1] in f:
                    res[i]["SKDW"+"_"+"KEY"]="".join(temp[index1[0]:index1[1]+2])
                    res[i]["SKDW"+"_"+"VALUE"]="".join(temp[index1[1]+2:index2[0]])
                else:
                    res[i]["SKDW"+"_"+"KEY"]="".join(temp[index1[0]:index1[1]+1])
                    res[i]["SKDW"+"_"+"VALUE"]="".join(temp[index1[1]+1:index2[0]])
                
                if len(temp)-1>index2[1] and temp[index2[1]+1] in f :
                    res[i]["SK"+"_"+"KEY"]="".join(temp[index2[0]:index2[1]+2])
                    res[i]["SK"+"_"+"VALUE"]="".join(temp[index2[1]+2:])
                else:
                    res[i]["SK"+"_"+"KEY"]="".join(temp[index2[0]:index2[1]+1])
                    res[i]["SK"+"_"+"VALUE"]="".join(temp[index2[1]+1:])

            if len(date)>18:
                pattern=r'\d{2,4}年\d{1,2}月\d{1,2}日|\d{2,4}\S\d{1,2}\S\d{1,2}|d{2,4}年\d{1,2}月\d{1,2}日\d{1,2}时\d{1,2}分|202\d?|\d{2,4}年\d{1,2}月'
                r=re.findall(pattern,date)
                if len(list(r))>0:
                    res[i]["IN_VALUE"]=r[0]
                    if len(list(r))>1:
                        res[i]["OUT_VALUE"]=r[1]
            break


result=res.copy()
for i in range(len(res)):
    for key,value in list(res[i].items()):
        first=key.split("_")[0]
        second=key.split("_")[1]
        if key=="NAME_VALUE":
            result[i]["NAME_VALUE"]=result[i]["NAME_VALUE"].replace("病历记录","")
        if key=="PH_VALUE":
            result[i]["PH_VALUE"]=result[i]["PH_VALUE"].replace(" ","")
            mo=r'[a-z|A-Z|.]{1,20}'
            r=re.findall(mo,value)
            if len(r)>0:
                result[i]["PH_VALUE"]=result[i]["PH_VALUE"].replace(r[0],"")
        if key=="GENDER_VALUE":
            mo=r'[男|女]'
            r=re.findall(mo,value)
            if len(r)>0:
                result[i]["GENDER_VALUE"]=r[0]
            else:
                result[i]["GENDER_VALUE"]="/"
        if key=="AGE_VALUE":
            mo=r'[\d{1,2}岁]'
            r=re.findall(mo,value)
            if len(r)>0:
                result[i]["GENDER_VALUE"]=r[0]
            else:
                result[i]["GENDER_VALUE"]="/"
        if second=="VALUE" and value=="":
            del result[i][key]

# %%
import csv
def insertcsv(csvpath,filename,datajson):
    
    file=open(csvpath,'r',encoding='utf-8')
    keys=[]
    for key in datajson:
        keys.append(key)
    
    datas=csv.reader(file)
    datas=list(datas)
    i=int(len(datas))
    
    for f in range(i):
        if(datas[f][0]==filename):
            for key in keys:
                if datas[f][2]==key:
                    datas[f][3]=datajson[key]
    
    file.close()
    with open(csvpath, 'w', encoding='utf-8',newline='') as csvfile:
        writer  = csv.writer(csvfile)
        for row in datas:
            writer.writerow(row)

# %%
def return_res(r,dic,label2token):
    for key,value in r.items():
        first=key.split("_")[0]
        second=key.split("_")[1]
        if second=="VALUE" and label2token[first] in list(dic.keys()):
            dic[label2token[first]]=value
    
    for key,value in r.items():
        first=key.split("_")[0]
        second=key.split("_")[1]
        if second=="KEY" and label2token[first] in list(dic.keys()) and dic[label2token[first]]=="无":
            dic[label2token[first]]="/"

    return dic

# %%
mark=[]
r={}
for i in range(len(filename)):
    #购药发票
    medicines_invoice={
        "票据代码":"无","票据号码":"无","校验码":"无",
        "开票日期":"无","收款人":"无","复核人":"无","价税合计（大写）":"无","（小写）":"无"
        }
    #门诊发票
    outpatient_invoice={
        "性别":"无","票据代码":"无","票据号码":"无","校验码":"无","开票日期":"无","收款单位":"无",
        "收款人":"无","复核人":"无","医疗机构类型":"无","医保类型":"无","合计金额（大写）":"无","（小写）":"无",
        "诊查费":"无","检查费":"无","化验费":"无","治疗费":"无","手术费":"无","卫生材料费":"无",
        "西药费":"无","中药饮片":"无","中成药费":"无","一般诊疗费":"无","床位费":"无","护理费":"无",
        "挂号费":"无","其他收费项目":"无","医保统筹基金支付":"无","统筹支付":"无","个人现金支付":"无","个人账户支付":"无",
        "个人自付":"无","其他支付":"无","自付一":"无","自付二":"无"
    }
    #住院发票
    hospitalization_invoice={
        "性别":"无","入院日期":"无","出院日期":"无","住院天数":"无","票据代码":"无","票据号码":"无","校验码":"无","开票日期":"无","收款单位":"无",
        "收款人":"无","复核人":"无","医疗机构类型":"无","医保类型":"无","合计金额（大写）":"无","（小写）":"无",
        "诊查费":"无","检查费":"无","化验费":"无","治疗费":"无","手术费":"无","卫生材料费":"无",
        "西药费":"无","中药饮片":"无","中成药费":"无","一般诊疗费":"无","床位费":"无","护理费":"无",
        "挂号费":"无","其他收费项目":"无","医保统筹基金支付":"无","统筹支付":"无","个人现金支付":"无","个人账户支付":"无",
        "个人自付":"无","其他支付":"无","自付一":"无","自付二":"无"
    }
    for item in traindata:
        if filename[i].split(".")[0]==item["图名"].split(".")[0] and item["图名"] in filename[i] and item["图名"] not in mark and item["材料类型"]=="购药发票":
            mark.append(item["图名"])
            r[item["图名"]]=medicines_invoice
        elif filename[i].split(".")[0]==item["图名"].split(".")[0] and item["图名"] in filename[i] and item["图名"] not in mark and item["材料类型"]=="门诊发票":
            mark.append(item["图名"])
            r[item["图名"]]=outpatient_invoice
        elif filename[i].split(".")[0]==item["图名"].split(".")[0] and item["图名"] in filename[i] and item["图名"] not in mark and item["材料类型"]=="住院发票":
            mark.append(item["图名"])
            r[item["图名"]]=hospitalization_invoice

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
import os
dirpath=os.environ["HF_HOME"]

discharge_tokenizer = AutoTokenizer.from_pretrained("zhenglianchi/dis-ner",cache_dir=dirpath)

discharge_model = AutoModelForTokenClassification.from_pretrained("zhenglianchi/dis-ner",cache_dir=dirpath)

discharge_ner = pipeline("token-classification", tokenizer=discharge_tokenizer,model=discharge_model)

medicines_tokenizer = AutoTokenizer.from_pretrained("zhenglianchi/med-ner",cache_dir=dirpath)

medicines_model = AutoModelForTokenClassification.from_pretrained("zhenglianchi/med-ner",cache_dir=dirpath)

medicines_ner = pipeline("token-classification", tokenizer=medicines_tokenizer,model=medicines_model)

outpatient_hospitalization_tokenizer = AutoTokenizer.from_pretrained("zhenglianchi/fp-ner",cache_dir=dirpath)

outpatient_hospitalization_model = AutoModelForTokenClassification.from_pretrained("zhenglianchi/fp-ner",cache_dir=dirpath)

outpatient_hospitalization_ner = pipeline("token-classification", tokenizer=outpatient_hospitalization_tokenizer,model=outpatient_hospitalization_model)

# %%
import ast
import os

def get_imlist(path):
        return [os.path.join(path,f) for f in os.listdir(path)]

path="test_out_txt"
pathlist=get_imlist(path)

def get_name_list(path):
    with open(path,encoding="utf-8") as f:
        lists=ast.literal_eval(f.readline())
        #获取到文本列表
        return os.path.basename(path),lists

def get_str(listdata):
    res=""
    for item in listdata:
        res=res+str(item)
    return res

def return_res(res,label2token,datajson):
    test={}
    item=""
    for i in range(len(res)):
        type1=res[i]["entity"][2:]
        if i==(len(res)-1):
            type3=res[i-1]["entity"][2:]
            if type1==type3:
                item+=res[i]["word"]
                if type1 not in test.keys():
                    test[type1]=item
            else:
                item+=res[i]["word"]
                if type1 not in test.keys():
                    test[type1]=item
            break

        type2=res[i+1]["entity"][2:]
        if type1 != type2:
            item+=res[i]["word"]
            if type1 not in test.keys():
                test[type1]=item
            item=""
        else:
            item+=res[i]["word"]
    

    for key,value in test.items():
        key=label2token[key]
        value=value.replace("#","")
        if key in datajson.keys() and (datajson[key]=="空" or datajson[key]=="无"):
            datajson[key]=value

    return datajson

# %%
from datasets import load_dataset
result={}

dis_token2label={"性别":"G","年龄":"A","医院名称":"N","组织机构代码":"C","医疗机构类型":"L","住院天数":"D","入院日期":"IN","出院日期":"OUT"}
dis_label2token={}
for key,value in dis_token2label.items():
    dis_label2token[value]=key


med_token2label={ "票据代码": "PD","票据号码": "PH","校验码": "JY",  "开票日期": "PR", 
"收款人": "SR", "复核人": "FR", "价税合计（大写）":"JD","（小写）":"JX"}
med_label2token={}
for key,value in med_token2label.items():
    med_label2token[value]=key


fp_token2label = {"性别": "G", "入院日期":"IN","出院日期":"OUT","住院天数": "D", "票据代码": "PD","票据号码": "PH", "校验码": "JY", "开票日期": "PR", 
"收款单位": "SD", "收款人": "SR", "复核人": "FR", "医疗机构类型": "L", "医保类型": "YL", "诊查费": "ZC", 
"检查费": "JC",  "化验费": "HY", "治疗费": "ZL", "手术费": "S",  "卫生材料费": "WC", "西药费": "WY", 
"中药饮片": "ZY",  "中成药费": "ZCY", "一般诊疗费": "YZL","床位费": "CW",  "护理费": "HL",  "挂号费": "GH", 
"其他收费项目": "ELE", "合计金额（大写）": "HJD", "（小写）": "HJX",  "医保统筹基金支付": "YTC",
"统筹支付": "TC", "个人现金支付": "PX", "个人账户支付": "PP", 
"个人自付": "PO", "其他支付": "ELP",  "自付一": "POO", "自付二": "PW"}
fp_label2token={}
for key,value in fp_token2label.items():
    fp_label2token[value]=key


testdata=load_dataset("csv",data_files="datasets/onlyBert.csv")
dataset=testdata["train"]
mark=[]
for item in pathlist:
    filename,txtlist=get_name_list(item)
    filename=filename.replace(".txt","")
    txtstr=get_str(txtlist)
    discharge_summary={
        "性别":"无","年龄":"无","医院名称":"无",
        "组织机构代码":"无","医疗机构类型":"无","入院日期":"无","出院日期":"无","住院天数":"无"
        }
    for item in dataset:
        if filename.split(".")[0]==item["图名"].split(".")[0] and item["图名"] in filename and item["图名"] not in mark and item["材料类型"]=="出院小结":
            mark.append(item["图名"])
            res=discharge_ner(txtstr)
            datajson=return_res(res,dis_label2token,discharge_summary)
            result[item["图名"]]=datajson

        elif filename.split(".")[0]==item["图名"].split(".")[0] and item["图名"] in filename and item["图名"] not in mark and item["材料类型"]=="购药发票":
            mark.append(item["图名"])
            res=medicines_ner(txtstr)
            datajson=return_res(res,med_label2token,r[item["图名"]])
            result[item["图名"]]=datajson

        elif filename.split(".")[0]==item["图名"].split(".")[0] and item["图名"] in filename and item["图名"] not in mark and item["材料类型"]=="门诊发票":
            mark.append(item["图名"])
            res=outpatient_hospitalization_ner(txtstr)
            datajson=return_res(res,fp_label2token,r[item["图名"]])
            result[item["图名"]]=datajson

        elif filename.split(".")[0]==item["图名"].split(".")[0] and item["图名"] in filename and item["图名"] not in mark and item["材料类型"]=="住院发票":
            mark.append(item["图名"])
            res=outpatient_hospitalization_ner(txtstr)
            datajson=return_res(res,fp_label2token,r[item["图名"]])
            result[item["图名"]]=datajson
# Out:
# Using custom data configuration default-a1b9cbc5f987c257
# Downloading and preparing dataset csv/default to D:\hugging-face\datasets\csv\default-a1b9cbc5f987c257\0.0.0\51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset csv downloaded and prepared to D:\hugging-face\datasets\csv\default-a1b9cbc5f987c257\0.0.0\51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
result
# Out:
# {'0055f88d65_20.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '101',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '陆万式仟佰鑫拾伍元随角建',
#   '（小写）': '无',
#   '诊查费': '2.00',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '0.00',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '0063d2aff7_11.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '伍万玖仟零玖拾肆元陆角捌分590',
#   '（小写）': '59094.68',
#   '诊查费': '无',
#   '检查费': '220.',
#   '化验费': '2846.404',
#   '治疗费': '6324.58',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '.16.00',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '：',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '00936aea-5d2c-4d65-9244-be1b032da0a6.jpg': {'性别': '男',
#   '票据代码': '无',
#   '票据号码': '54013873074401',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '：',
#   '医保类型': '外地医保',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '0217a4d40b_7.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '工',
#   '医保类型': '市保职',
#   '合计金额（大写）': '肆万贰仟肆佰毒贰无集角贰分￥：42402.72',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '24.00',
#   '化验费': '费',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '材',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '000',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '0292e2d30a_2.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '140602',
#   '票据号码': '00068988',
#   '校验码': '无',
#   '开票日期': '2021-04-12',
#   '收款单位': '山西省肿瘤医院（山西省第三人民医院）人：93',
#   '收款人': '36',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '肆仟壹佰柒拾陆元玖角肆分（小写',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '1',
#   '化验费': '**',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '219.00',
#   '西药费': '1752.74',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '75.00',
#   '护理费': '.00',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '0.',
#   '个人自付': '无',
#   '其他支付': '0.00',
#   '自付一': '无',
#   '自付二': '无'},
#  '0321be0b4f_47.jpg': {'性别': '男',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '00112273',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '人（签章）：1720201230日',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '地联网结算',
#   '合计金额（大写）': '陆万陆仟零叁拾壹元玖角玖分66031.99',
#   '（小写）': '：',
#   '诊查费': '无',
#   '检查费': '失',
#   '化验费': '输',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '58336.44242.00费',
#   '中药饮片': '无',
#   '中成药费': '费',
#   '一般诊疗费': '无',
#   '床位费': '手术260.00',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '款',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '血',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '费',
#   '自付二': '无'},
#  '0491b63e4f_5.jpg': {'性别': '男',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '0750fe1c05_7.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '伍万陆仟捌佰肆拾伍元捌角玖分￥：56845.89',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '成',
#   '化验费': '无',
#   '治疗费': '费',
#   '手术费': '品收',
#   '卫生材料费': '理',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '料',
#   '护理费': '无',
#   '挂号费': '药',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '金',
#   '统筹支付': '助（公',
#   '个人现金支付': '无',
#   '个人账户支付': '0',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '075a5e931b_10.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '2913000680',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '琳一医院',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '医保丹',
#   '医保类型': '无',
#   '合计金额（大写）': '捌仟伍佰玖壹元查角玖',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '介',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '费2015',
#   '西药费': '材费2',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '6191',
#   '个人账户支付': '无',
#   '个人自付': '：',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '080a3ce8ab_9.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': 'Ne00071591',
#   '校验码': '无',
#   '开票日期': '20121年04月19',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '医保类型：异地',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '成',
#   '检查费': '疗',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '43',
#   '卫生材料费': '0',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '162',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '自费0010382',
#   '个人账户支付': '0.',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '09690395-1387-489b-b237-ee7c8b01f1f9.jpg': {'性别': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '12534289',
#   '开票日期': '无',
#   '收款单位': '→）：44040',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '1423.20壹仟肆佰系拾叁元贰角整',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '137bbb21f0_5.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '410602',
#   '票据号码': '00007277',
#   '校验码': '1854',
#   '开票日期': '2021-05-14',
#   '收款单位': '癌款人：张梦茜',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '（小写）178',
#   '（小写）': '44.87',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '1434.',
#   '治疗费': '2355.08',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '0',
#   '统筹支付': '无',
#   '个人现金支付': '金',
#   '个人账户支付': '0',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '5302.77',
#   '自付二': '现'},
#  '138cd626d0e14f22a8775d4a48e00023_32.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '003',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '材',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '支',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '156e0c1a40_8.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '00011369',
#   '校验码': '3191',
#   '开票日期': '2021-02-09',
#   '收款单位': '鞋聚人林德佳',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '省保居民医保',
#   '合计金额（大写）': '壹拾壹万玖仟染佰捌拾玖元捌角柒分(小',
#   '（小写）': '789.87',
#   '诊查费': '无',
#   '检查费': '81',
#   '化验费': '8,430.56',
#   '治疗费': '4188.31',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '98215.84',
#   '中药饮片': '报',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '3,150.00',
#   '护理费': '021001',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '第人',
#   '统筹支付': '无',
#   '个人现金支付': '：',
#   '个人账户支付': '0.00',
#   '个人自付': '，',
#   '其他支付': '0.00',
#   '自付一': '无',
#   '自付二': '无'},
#  '166c89724f_5.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '410602',
#   '票据号码': '00026651',
#   '校验码': '2c05',
#   '开票日期': '2021-02-09',
#   '收款单位': '：宋梦收款人：',
#   '收款人': '无',
#   '复核人': '宋梦',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '陆万壹仟陆佰壹拾贰元壹角玖分整（小写',
#   '（小写）': '616',
#   '诊查费': '无',
#   '检查费': '9859.20',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '16833.77',
#   '西药费': '978.00',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '36000',
#   '护理费': '69',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '17018.',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '0付',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '178d6d866c_13.jpg': {'性别': '女',
#   '入院日期': '21-02-23',
#   '出院日期': '21-03-22',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '护理',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '185c90ebbf_8.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '50043',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '5',
#   '化验费': '010',
#   '治疗费': '2021011308',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '.',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '0',
#   '自付一': '无',
#   '自付二': '无'},
#  '190e46fd3f_76.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '肆万伍仟零玖拾华元贰角捌分45097.28',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '手',
#   '治疗费': '无',
#   '手术费': '800',
#   '卫生材料费': '中成',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '费',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '203c4bc25a_7.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '370602',
#   '票据号码': '01003570',
#   '校验码': '无',
#   '开票日期': '2021-03-25',
#   '收款单位': '济南市中心医院款人：',
#   '收款人': '无',
#   '复核人': '63',
#   '医疗机构类型': '综合性医',
#   '医保类型': '市医保职工',
#   '合计金额（大写）': '肆万肆任捌佰肆拾玖元陆角捌分（小写',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '3',
#   '化验费': '37011219831204**',
#   '治疗费': '349.00636.60',
#   '手术费': '无',
#   '卫生材料费': '9',
#   '西药费': '44849.68',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '39.',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '30950.90',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '0.00',
#   '个人自付': '无',
#   '其他支付': '0.00',
#   '自付一': '无',
#   '自付二': '无'},
#  '227e78cc92_15.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': 'No.20002072',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '140',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '44000',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '228c171240_11.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '410602',
#   '票据号码': '00059206',
#   '校验码': '3327',
#   '开票日期': '2021-05-11',
#   '收款单位': '规上收款',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '210470082370',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '药836.64',
#   '西药费': '无',
#   '中药饮片': '自',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '37800',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '92员',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '0.00',
#   '个人自付': '无',
#   '其他支付': '支',
#   '自付一': '无',
#   '自付二': '无'},
#  '229f51336f_7.jpg': {'性别': '男',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '410602',
#   '票据号码': '00058633',
#   '校验码': '2999',
#   '开票日期': '2021-04-15',
#   '收款单位': '核人：线上收款',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '伍万肆仟伍佰参拾伍元陆角垫（小写）54535.60',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '105.20',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '他',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '助',
#   '统筹支付': '住',
#   '个人现金支付': '筹',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '付产',
#   '自付一': '无',
#   '自付二': '无'},
#  '232bd41523_0.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '02-',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '26830907制',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '00',
#   '化验费': '无',
#   '治疗费': '费',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '20',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '免',
#   '医保统筹基金支付': '费',
#   '统筹支付': '务',
#   '个人现金支付': '无',
#   '个人账户支付': '财',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '235b9cbfce_15.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '0006239520',
#   '校验码': '无',
#   '开票日期': '年12月23',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '陆万球仟零陆拾参元伍角整铁',
#   '（小写）': '64,',
#   '诊查费': '无',
#   '检查费': '.001442',
#   '化验费': '20年12月2日',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '8',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '.',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '237dffa017_8.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '00070759',
#   '校验码': '无',
#   '开票日期': '2021年04月16',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '长沙专：制',
#   '医保类型': '0个人',
#   '合计金额（大写）': '无',
#   '（小写）': '77',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '16334.',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '240a25e584_16.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': 'No017023',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '/',
#   '收款人': '46613.60',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '新农余',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '20017023',
#   '化验费': ',61',
#   '治疗费': '36,327.26',
#   '手术费': '5',
#   '卫生材料费': '无',
#   '西药费': '20',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '507.2810',
#   '护理费': '168.609705.90',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '240a25e584_17.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '办人',
#   '收款人': '沈',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '2',
#   '化验费': '1',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '477.50',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '520.00465.90',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '240a25e584_18.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '01702302',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '核：经办人：陈敏/L17043',
#   '收款人': '2020-03',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '壹佰零贰元贰角柴分总金额小写',
#   '（小写）': '102.27',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '240a25e584_19.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': 'No012',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '杨伟玲',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '伍佰陆拾柴元陆角陆分总金额（小写）7.',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '567.66',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '240a25e584_20.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': 'No012',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '杨伟玲',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '肆佰玖拾伍元陆角伍分',
#   '（小写）': '495.65',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '250e9e8d6f_17.jpg': {'性别': '男',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '410602',
#   '票据号码': '17004721',
#   '校验码': '无',
#   '开票日期': '2021-05-11',
#   '收款单位': '隆阳市中心医院收款',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '陆万零玖拾染元壹角捌分整（小写',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '用',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '住院',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '中',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '0',
#   '统筹支付': '费',
#   '个人现金支付': '基',
#   '个人账户支付': '公',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '：',
#   '自付二': '无'},
#  '258c82ac1e_14.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '00608129150300',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '别',
#   '医保类型': '异地医工',
#   '合计金额（大写）': '伍万肆仟柴佰贰拾赋元54722',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '258efbbe19_7.jpg': {'性别': '无',
#   '入院日期': '2020-12-30',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2021-02-01',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '柒万玖仟玖佰伍拾壹圆玖角叁分79951.93统筹',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '262ecb1902_5.jpg': {'性别': '男',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '410602',
#   '票据号码': '00026892',
#   '校验码': '9a73',
#   '开票日期': '2021-03-17',
#   '收款单位': '无',
#   '收款人': '款人',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '壹万贰仟伍佰陆拾捌元壹分整（小写）12568.01医',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '261',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '诊',
#   '西药费': '8.',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '药',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '人',
#   '个人现金支付': '无',
#   '个人账户支付': '0',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '：',
#   '自付二': '：'},
#  '275f2fffe0_5.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '壹万凳仟壹佰肆拾元贰角整：天,',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '疗',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '28304e7bacc542b9af5b141630bd93a4_16.jpg': {'性别': '无',
#   '票据代码': '无',
#   '票据号码': '1901',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '729.20',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '28304e7bacc542b9af5b141630bd93a4_23.jpg': {'性别': '男',
#   '票据代码': '无',
#   '票据号码': '1901120890',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '单位（益章',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '院',
#   '医保类型': '无',
#   '合计金额（大写）': '肆佰捌拾陆元架角整￥486.',
#   '（小写）': '型',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '28304e7bacc542b9af5b141630bd93a4_25.jpg': {'性别': '男',
#   '票据代码': '无',
#   '票据号码': '2019)1901120890',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '/',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '叁元捌角整',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '28304e7bacc542b9af5b141630bd93a4_29.jpg': {'性别': '男',
#   '票据代码': '无',
#   '票据号码': '1901120890',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '伍佰捌拾玖元整9',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '28304e7bacc542b9af5b141630bd93a4_39.jpg': {'性别': '男',
#   '票据代码': '无',
#   '票据号码': '1901120890',
#   '校验码': '无',
#   '开票日期': '2020/03/30',
#   '收款单位': '/',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '壹拾捌元捌角整',
#   '（小写）': '型',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '318c99f4eb_13.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '8',
#   '票据代码': '无',
#   '票据号码': '00001863',
#   '校验码': '无',
#   '开票日期': '2021-01-07',
#   '收款单位': '国医学人：01680收款单位（章）：',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '地诊',
#   '合计金额（大写）': '壹拾壹万捌仟肆佰陆拾叁元柒角肆分118463.74(小写）',
#   '（小写）': '专医',
#   '诊查费': '无',
#   '检查费': '701751.9875',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '0076',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '查',
#   '护理费': '料学',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '0.00',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '338665bf-d188-4adf-b24e-0499911dde6f.jpg': {'性别': '女',
#   '票据代码': '无',
#   '票据号码': '1901114889',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '肆元角',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '338665bf-d188-4adf-b24e-0499911dde6f1.jpg': {'性别': '女',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '壹倍陆拾元玖角整160.00',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '341aa6aadd_16.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '0000046600000466',
#   '校验码': '无',
#   '开票日期': '2021-01-27',
#   '收款单位': '北京大学人民医',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '综',
#   '医保类型': '城镇职工',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '7383.0090.003.50卫',
#   '治疗费': '无',
#   '手术费': '费208诊',
#   '卫生材料费': '服',
#   '西药费': '疗',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '700',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '10215.71',
#   '统筹支付': '无',
#   '个人现金支付': '21352.678：',
#   '个人账户支付': '0.00',
#   '个人自付': '无',
#   '其他支付': '0.00',
#   '自付一': '无',
#   '自付二': '无'},
#  '362a35a789_9.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '刘迪收款单',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '0000092280女',
#   '医保类型': '无',
#   '合计金额（大写）': '叁万肆仟参佰贰拾贰元玖角玖分34,322.99住',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '159.001.741701.144.8062.532.5244.002.946.489.60102.06.903.',
#   '化验费': '出',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '0.00',
#   '统筹支付': '付',
#   '个人现金支付': '自费：',
#   '个人账户支付': '无',
#   '个人自付': '：：',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '363c6c6065_14.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '2613000575',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '哈滨医科大学阴属第一医院',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '别哈市',
#   '医保类型': '城乡',
#   '合计金额（大写）': '无',
#   '（小写）': '55.88',
#   '诊查费': '无',
#   '检查费': '11000氧',
#   '化验费': '1,551.40',
#   '治疗费': 'No26130005752020年18',
#   '手术费': '查',
#   '卫生材料费': '无',
#   '西药费': ',474.44',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '403.00',
#   '护理费': '291.00',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '364df9aa44_12.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '1015027082',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '45.00',
#   '检查费': '无',
#   '化验费': '1092.20',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '96.00',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '疗',
#   '统筹支付': '员',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '371ae02751_11.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '101502718',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '黑龙江省‧医疗住',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '陆仟柒佰拾壹元肆角整',
#   '（小写）': '6741.40',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '375cbe819a_6.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '00001851',
#   '校验码': '无',
#   '开票日期': '2021年5月14日',
#   '收款单位': '垦中心医院款单（）票',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '壹万叁仟陆佰玖拾肆元伍角玖分小写13694.59金',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '801C',
#   '治疗费': '药',
#   '手术费': '检',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '费',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '3858d114-5b86-4888-8894-a151ea237fc3.jpg': {'性别': '无',
#   '票据代码': '无',
#   '票据号码': '1613954-04NO',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '自费',
#   '合计金额（大写）': '叁佰伍拾捌元伍角整月01日19合计',
#   '（小写）': '型',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '385a99a3af_10.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '000135861',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '费',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '34112.448.96277.93',
#   '手术费': '人',
#   '卫生材料费': '无',
#   '西药费': '：',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '费',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '户',
#   '医保统筹基金支付': '无',
#   '统筹支付': '业：',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '4008efb3-27dc-4a2d-a49f-602b81f676815.jpg': {'性别': '无',
#   '票据代码': '无',
#   '票据号码': '30233994709032672',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '00',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '418b76773c_12.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '13',
#   '票据代码': '无',
#   '票据号码': '403011712',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '渠',
#   '合计金额（大写）': '无',
#   '（小写）': '型',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '4216ea17-9d04-4c13-b15d-f14682b71b00.jpg': {'性别': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '壹元角',
#   '（小写）': '型',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '/',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '4216ea17-9d04-4c13-b15d-f14682b71b001.jpg': {'性别': '女',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '(107)支',
#   '收款人': '1237',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '贰肆拾壹元会角',
#   '（小写）': '.20',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '421dca409d_9.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '22',
#   '票据代码': '豫财4102',
#   '票据号码': 'NO.09737',
#   '校验码': '无',
#   '开票日期': '2021年02月14日',
#   '收款单位': '新乡市中心医院2021/2/18整（签章）：月日',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '型',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '1834015.00',
#   '护理费': '材',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '434b242e9c_2.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '陆仟伍佰贰拾伍元肆角伍分6525.45（小写）',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '治',
#   '化验费': '氧',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '交',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '434baef0ff_30.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '天津市医疗住院',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '：',
#   '医保类型': '异地联网医',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '434f0cbe48_7.jpg': {'性别': '男',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '440602',
#   '票据号码': '00432050',
#   '校验码': '无',
#   '开票日期': '2021-04-09',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '5062',
#   '医疗机构类型': '无',
#   '医保类型': '医保',
#   '合计金额（大写）': '壹万柒仟零柒拾陆元捌角肆分（小）',
#   '（小写）': '17,076.84',
#   '诊查费': '无',
#   '检查费': '10745.90',
#   '化验费': '518.002',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '含',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '54.00',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '技',
#   '其他支付': '0.00',
#   '自付一': '无',
#   '自付二': '无'},
#  '445a0db9d6bf43a7859265c0e3f38c07_12.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': 'No002930',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '章赵',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '91141510.0085.24',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '449ac5ccfb_0.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '000.00',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '0.',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '449ac5ccfb_1.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '4030780682',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '453d99d8de_9.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '2',
#   '票据代码': '无',
#   '票据号码': '46060200007669',
#   '校验码': 'ba38',
#   '开票日期': '无',
#   '收款单位': '海南省医住',
#   '收款人': '南',
#   '复核人': '邱',
#   '医疗机构类型': '综合性医',
#   '医保类型': '无',
#   '合计金额（大写）': '壹仟伍佰策拾贰元登角贰分（1',
#   '（小写）': ',572.12',
#   '诊查费': '无',
#   '检查费': '184.9018.',
#   '化验费': '00',
#   '治疗费': '53.80',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '907.25',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '454a801113714a2791a5d20ef0099c17_NOURALLAH GHAEMINEZHAD_0.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '14912.85',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '45cbfa3bd0994083b9d1295ffadeb6d1_8.png': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '0000013213221',
#   '校验码': '无',
#   '开票日期': '2020-18',
#   '收款单位': '沈阳市第七人民医收5Q025',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '异地医疗保',
#   '医保类型': '无',
#   '合计金额（大写）': '叁万零伍佰肆拾壹元伍角肆分印（小写）30541.54',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '费',
#   '西药费': '费',
#   '中药饮片': '无',
#   '中成药费': '费',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '声',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '费',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '费，',
#   '自付一': '无',
#   '自付二': '无'},
#  '45f04ade2e_10.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '0',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '400004',
#   '中药饮片': '费',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '45ffd59739554054b1301a3bd451841a_14.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '12',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '59.989.91',
#   '西药费': '2211590',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '462faf8bb9_8.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '370602',
#   '票据号码': '13004975',
#   '校验码': '7095',
#   '开票日期': '20210102',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '9563',
#   '医疗机构类型': '综合医',
#   '医保类型': '无',
#   '合计金额（大写）': '贰万贰仟陆佰柴拾壹元零壹分（小写',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '11',
#   '化验费': '21021****',
#   '治疗费': '95.55',
#   '手术费': '无',
#   '卫生材料费': '9617',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '315.00',
#   '护理费': '227',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '0.00',
#   '个人自付': '无',
#   '其他支付': '0.00',
#   '自付一': '无',
#   '自付二': '无'},
#  '469b0a96bb_5.jpg': {'性别': '男',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '00035984',
#   '校验码': '无',
#   '开票日期': '2021-05-10',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '4.',
#   '化验费': '50227',
#   '治疗费': '收',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '1540.0030343.552520.',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '16690.98自98',
#   '个人账户支付': '0',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '46b24355de_7.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '2021/4/12',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '陆万壹仟柴佰贰拾伍元零伍分整收61',
#   '（小写）': '725.05',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '0',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '46b91dbe47_15.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '民沼年月12021日',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '综合三',
#   '医保类型': '居民',
#   '合计金额（大写）': '柒万柒仟伍佰零捌元玖角零分77508.90',
#   '（小写）': '：',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '款',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '用',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '46c0e3e2e4_7.jpg': {'性别': '男',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '410602',
#   '票据号码': '00058633',
#   '校验码': '2999',
#   '开票日期': '202-04-15',
#   '收款单位': '核人：线上收款',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '伍万肆仟伍佰参拾伍元陆角垫（小写）54535.60',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '105.20',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '他',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '助',
#   '统筹支付': '住',
#   '个人现金支付': '筹',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '付产',
#   '自付一': '无',
#   '自付二': '无'},
#  '46f1f653eb_7.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '人',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '46f1f653eb_9.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '1702NO.',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '无',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '38.',
#   '化验费': '216.00',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '47164445-d95f-4073-b80c-9e65cda100f0.png': {'性别': '男',
#   '票据代码': '111',
#   '票据号码': '0000563',
#   '校验码': '无',
#   '开票日期': '2021-01-13',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '城镇职工',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '无',
#   '治疗费': '无',
#   '手术费': '无',
#   '卫生材料费': '无',
#   '西药费': '无',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '二',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '无',
#   '个人账户支付': '0.000.00',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '473e34d1ac_8.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '2913000548',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '市医保',
#   '合计金额（大写）': '无',
#   '（小写）': '.272',
#   '诊查费': '无',
#   '检查费': '403.504',
#   '化验费': '9021年03月19日',
#   '治疗费': '30',
#   '手术费': '9.20',
#   '卫生材料费': '15306.8228951.',
#   '西药费': '468008',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '326',
#   '个人账户支付': '无',
#   '个人自付': '无',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '473ea3f018_5.jpg': {'性别': '女',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '410602',
#   '票据号码': '00011395',
#   '校验码': '3363',
#   '开票日期': '2021-01-18',
#   '收款单位': '河南省医疗麻',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '城乡居民',
#   '医保类型': '无',
#   '合计金额（大写）': '伍万玖仟致佰糊拾制元脑角集分处（',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '001',
#   '治疗费': '无',
#   '手术费': '8.00',
#   '卫生材料费': '36',
#   '西药费': '48',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '无',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '无',
#   '统筹支付': '无',
#   '个人现金支付': '基',
#   '个人账户支付': '0.00',
#   '个人自付': '户',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '付'},
#  '475fd08ae1_27.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '豫财4102',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '年02月09日',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '城乡',
#   '医保类型': '居',
#   '合计金额（大写）': '陆仟叁佰零玖元肆角伍分预微',
#   '（小写）': '无',
#   '诊查费': '无',
#   '检查费': '无',
#   '化验费': '理',
#   '治疗费': '费',
#   '手术费': '无',
#   '卫生材料费': '：',
#   '西药费': '查费',
#   '中药饮片': '无',
#   '中成药费': '无',
#   '一般诊疗费': '无',
#   '床位费': '自',
#   '护理费': '无',
#   '挂号费': '无',
#   '其他收费项目': '无',
#   '医保统筹基金支付': '付',
#   '统筹支付': '）',
#   '个人现金支付': '无',
#   '个人账户支付': '无',
#   '个人自付': '：￥',
#   '其他支付': '无',
#   '自付一': '无',
#   '自付二': '无'},
#  '477a1de1ff_13.jpg': {'性别': '无',
#   '入院日期': '无',
#   '出院日期': '无',
#   '住院天数': '无',
#   '票据代码': '无',
#   '票据号码': '2613002937',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款单位': '无',
#   '收款人': '无',
#   '复核人': '无',
#   '医疗机构类型': '无',
#   '医保类型': '省医',
#   '合计金额（大写）': '无',
#   '（小写）': '无',
#   '诊查费': '305420.001',
#   '检查费': '262.30',
# ...
#   '校验码': '011816824315135',
#   '开票日期': '2022年04月02日',
#   '收款人': '赵笑林',
#   '复核人': '无',
#   '价税合计（大写）': '壹拾叁圆叁角贰分（小写',
#   '（小写）': '无'},
#  'fp_107': {'票据代码': '0370021002',
#   '票据号码': '509924',
#   '校验码': '854311059017143',
#   '开票日期': '2022年04月02日',
#   '收款人': '无',
#   '复核人': '王天姿',
#   '价税合计（大写）': '壹拾肆圆叁角捌分',
#   '（小写）': '无'},
#  'fp_108': {'票据代码': '0110021006',
#   '票据号码': '584400全',
#   '校验码': '106145555733413',
#   '开票日期': '2022年04月02日',
#   '收款人': '林铖倩',
#   '复核人': '无',
#   '价税合计（大写）': '壹拾贰圆参角伍分（小',
#   '（小写）': '无'},
#  'fp_109': {'票据代码': '0110022002',
#   '票据号码': '无',
#   '校验码': '847345720736454',
#   '开票日期': '2022年04月14日',
#   '收款人': '无',
#   '复核人': '王军月',
#   '价税合计（大写）': '叁拾圆整',
#   '（小写）': '无'},
#  'fp_110': {'票据代码': '0110021007',
#   '票据号码': '227407',
#   '校验码': '120458678947532',
#   '开票日期': '2022年04月06日',
#   '收款人': '庄岩',
#   '复核人': '隋芳',
#   '价税合计（大写）': '贰圆壹角贰分',
#   '（小写）': '无'},
#  'fp_111': {'票据代码': '0110022001',
#   '票据号码': '947840',
#   '校验码': '028448582374040',
#   '开票日期': '2022年03月22日',
#   '收款人': '姜玲莉',
#   '复核人': '张成芳',
#   '价税合计（大写）': '陆拾玖圆柒角伍分',
#   '（小写）': '无'},
#  'fp_112': {'票据代码': '0110020008',
#   '票据号码': '无',
#   '校验码': '458946306711705',
#   '开票日期': '2022年03月22日',
#   '收款人': '续斌斌',
#   '复核人': '王秀娟',
#   '价税合计（大写）': '陆拾伍圆伍角',
#   '（小写）': '无'},
#  'fp_113': {'票据代码': '0110022002',
#   '票据号码': '120455',
#   '校验码': '067932494208799',
#   '开票日期': '2022年03月22日',
#   '收款人': '无',
#   '复核人': '马春晓',
#   '价税合计（大写）': '壹佰壹拾壹圆陆角壹分（小写）',
#   '（小写）': '无'},
#  'fp_114': {'票据代码': '0640020001',
#   '票据号码': '156379',
#   '校验码': '608385440517179',
#   '开票日期': '2022年03月22日',
#   '收款人': '田秀丽',
#   '复核人': '许丽杰',
#   '价税合计（大写）': '壹佰零玖圆零柒分',
#   '（小写）': '无'},
#  'fp_115': {'票据代码': '0110021007',
#   '票据号码': '389952',
#   '校验码': '014233510682892',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '贰拾伍圆肆角整',
#   '（小写）': '25.40'},
#  'fp_116': {'票据代码': '0110021007',
#   '票据号码': '389952',
#   '校验码': '176643747079720',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '贰拾肆圆玖角整',
#   '（小写）': '24.90'},
#  'fp_117': {'票据代码': '0110021007',
#   '票据号码': '389952',
#   '校验码': '014981972262218',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '无',
#   '价税合计（大写）': '参拾肆圆玖角整（',
#   '（小写）': '无'},
#  'fp_118': {'票据代码': '0110021007',
#   '票据号码': '389952',
#   '校验码': '077245855649119',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '贰拾玖圆玖角整',
#   '（小写）': '29.90'},
#  'fp_119': {'票据代码': '0110021007',
#   '票据号码': '389952',
#   '校验码': '116371538950084',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '伍拾圆伍角整',
#   '（小写）': '无'},
#  'fp_120': {'票据代码': '0110021007',
#   '票据号码': '389952',
#   '校验码': '137210059611052',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '参拾肆圆玖角整',
#   '（小写）': '无'},
#  'fp_121': {'票据代码': '0110021007',
#   '票据号码': '389952',
#   '校验码': '053203101631069',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '玖圆肆角整',
#   '（小写）': '9.40'},
#  'fp_122': {'票据代码': '0110021007',
#   '票据号码': '389953',
#   '校验码': '113094522719302',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '丽',
#   '价税合计（大写）': '参拾柒圆玖角整（小',
#   '（小写）': '37.90'},
#  'fp_123': {'票据代码': '0110021007',
#   '票据号码': '389953',
#   '校验码': '008115515355989',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '贰拾玖圆肆角整',
#   '（小写）': '29.40'},
#  'fp_124': {'票据代码': '0110021007',
#   '票据号码': '389953',
#   '校验码': '170010603874116',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '贰拾捌圆整',
#   '（小写）': '无'},
#  'fp_125': {'票据代码': '0110021007',
#   '票据号码': '389953',
#   '校验码': '168299379259307',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '壹拾玖圆玖角整（小',
#   '（小写）': '无'},
#  'fp_126': {'票据代码': '0110021007',
#   '票据号码': '389953',
#   '校验码': '015278591275964',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '贰拾肆圆玖角整',
#   '（小写）': '24.90'},
#  'fp_127': {'票据代码': '0110021007',
#   '票据号码': '389953',
#   '校验码': '013006878485019',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '壹拾玖圆玖角整（小',
#   '（小写）': '.'},
#  'fp_128': {'票据代码': '0110021007',
#   '票据号码': '389953',
#   '校验码': '017336058169499',
#   '开票日期': '2022年03月22日',
#   '收款人': '张翠江',
#   '复核人': '张丽',
#   '价税合计（大写）': '贰拾陆圆整',
#   '（小写）': '26.00'},
#  'fp_29': {'票据代码': '0110021005',
#   '票据号码': '538778国',
#   '校验码': '705641816809869',
#   '开票日期': '2021年12月05日',
#   '收款人': '刘添梅',
#   '复核人': '张丽',
#   '价税合计（大写）': '柒拾圆捌角(',
#   '（小写）': '70.80'},
#  'fp_30': {'票据代码': '0110021005',
#   '票据号码': '541409',
#   '校验码': '451401270728666',
#   '开票日期': '2021年12月05日',
#   '收款人': '刘添梅',
#   '复核人': '张丽杰',
#   '价税合计（大写）': '陆拾圆贰角壹分小',
#   '（小写）': '无'},
#  'fp_31': {'票据代码': '0120021003',
#   '票据号码': '612423',
#   '校验码': '058185977421317',
#   '开票日期': '2021年12月24日',
#   '收款人': '唐利芹',
#   '复核人': '牛艳',
#   '价税合计（大写）': '壹佰圆柒角整（',
#   '（小写）': '无'},
#  'fp_32': {'票据代码': '0120021003',
#   '票据号码': '612423',
#   '校验码': '174355004055270',
#   '开票日期': '2021年12月24日',
#   '收款人': '唐利芹',
#   '复核人': '牛艳',
#   '价税合计（大写）': '捌拾叁圆陆角伍分（小',
#   '（小写）': '无'},
#  'fp_33': {'票据代码': '01100210021',
#   '票据号码': '无',
#   '校验码': '825792339521830',
#   '开票日期': '2021年12月01日',
#   '收款人': '兰晓丹',
#   '复核人': '刘晓开',
#   '价税合计（大写）': '壹佰肆拾肆圆捌角(',
#   '（小写）': '无'},
#  'fp_34': {'票据代码': '0110020009',
#   '票据号码': '992845国',
#   '校验码': '107149345786686',
#   '开票日期': '2021年08月31日',
#   '收款人': '庄岩',
#   '复核人': '隋芳',
#   '价税合计（大写）': '叁拾贰圆肆角伍分',
#   '（小写）': '无'},
#  'fp_35': {'票据代码': '026973',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月01日',
#   '收款人': '余',
#   '复核人': '无',
#   '价税合计（大写）': '佰贰拾圆叁角壹分',
#   '（小写）': '无'},
#  'fp_36': {'票据代码': '1343763700213137002131134376',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月31日',
#   '收款人': '翟培宝',
#   '复核人': '孟小滨',
#   '价税合计（大写）': '贰万陆仟玖佰伍拾叁圆伍角伍分（小',
#   '（小写）': '26953.55'},
#  'fp_37': {'票据代码': '8751002131257',
#   '票据号码': '06',
#   '校验码': '无',
#   '开票日期': '2021年12月23日',
#   '收款人': '周源',
#   '复核人': '李博文',
#   '价税合计（大写）': '壹仟贰佰圆整',
#   '（小写）': '1200.00'},
#  'fp_38': {'票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2021年12月28日',
#   '收款人': '周源',
#   '复核人': '李博文',
#   '价税合计（大写）': '贰佰圆整',
#   '（小写）': '无'},
#  'fp_39': {'票据代码': '7440321411597849',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月11日',
#   '收款人': '詹瑞瑜',
#   '复核人': '谢同燕',
#   '价税合计（大写）': '陆仟捌佰拾肆圆捌角整',
#   '（小写）': '无'},
#  'fp_40': {'票据代码': '510021210986947',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年02月21日',
#   '收款人': '苏蕾蕾',
#   '复核人': '无',
#   '价税合计（大写）': '壹万肆仟壹佰零柴圆伍角整',
#   '（小写）': '无'},
#  'fp_41': {'票据代码': '110021311029593',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜',
#   '复核人': '茜',
#   '价税合计（大写）': '无',
#   '（小写）': '无'},
#  'fp_42': {'票据代码': '3-b1111002131No102959110021',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜李',
#   '复核人': '无',
#   '价税合计（大写）': '叁拾捌圆肆角荣分',
#   '（小写）': '无'},
#  'fp_43': {'票据代码': '110021311029592',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜',
#   '复核人': '无',
#   '价税合计（大写）': '壹万壹仟贰佰贰拾圆玖角叁分（小写',
#   '（小写）': '无'},
#  'fp_44': {'票据代码': '1029591100213111002131',
#   '票据号码': '9592',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李剑书',
#   '复核人': '茜',
#   '价税合计（大写）': '陆仟叁佰陆拾荣圆伍角贰分小',
#   '（小写）': '无'},
#  'fp_45': {'票据代码': '102959110021311029593',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜李',
#   '复核人': '茜',
#   '价税合计（大写）': '贰',
#   '（小写）': '无'},
#  'fp_46': {'票据代码': '110021311029593',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '无',
#   '复核人': '李茜',
#   '价税合计（大写）': '贰佰叁拾捌圆玖角肆分',
#   '（小写）': '无'},
#  'fp_47': {'票据代码': '00273411002041',
#   '票据号码': '0027347',
#   '校验码': '无',
#   '开票日期': '2022年03月30日',
#   '收款人': '无',
#   '复核人': '无',
#   '价税合计（大写）': '壹万伍仟圆整',
#   '（小写）': '无'},
#  'fp_48': {'票据代码': '110021311029592',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜',
#   '复核人': '无',
#   '价税合计（大写）': '无',
#   '（小写）': '无'},
#  'fp_49': {'票据代码': '959110021311100213',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜',
#   '复核人': '无',
#   '价税合计（大写）': '无',
#   '（小写）': '无'},
#  'fp_50': {'票据代码': '110031',
#   '票据号码': '1029592',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '无',
#   '复核人': '李剑书',
#   '价税合计（大写）': '无',
#   '（小写）': '无'},
#  'fp_51': {'票据代码': 'b1/11002131No102959',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李剑书',
#   '复核人': '茜',
#   '价税合计（大写）': '捌佰圆整',
#   '（小写）': '800.00'},
#  'fp_52': {'票据代码': '116021311029593',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜李',
#   '复核人': '无',
#   '价税合计（大写）': '贰拾伍圆玖角陆分',
#   '（小写）': '无'},
#  'fp_53': {'票据代码': '11002131',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '无',
#   '复核人': '无',
#   '价税合计（大写）': '肆佰玖拾圆壹角肆分（小',
#   '（小写）': '无'},
#  'fp_54': {'票据代码': '9110021311029592',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜',
#   '复核人': '无',
#   '价税合计（大写）': '无',
#   '（小写）': '无'},
#  'fp_55': {'票据代码': '10295911002131国',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜李',
#   '复核人': '无',
#   '价税合计（大写）': '贰佰圆整',
#   '（小写）': '200.00'},
#  'fp_56': {'票据代码': '61',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜',
#   '复核人': '李剑书',
#   '价税合计（大写）': '无',
#   '（小写）': '无'},
#  'fp_57': {'票据代码': '110021311029594',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜李',
#   '复核人': '无',
#   '价税合计（大写）': '贰佰玖拾圆整',
#   '（小写）': '290.00'},
#  'fp_58': {'票据代码': '02218322002031',
#   '票据号码': '无',
#   '校验码': '83',
#   '开票日期': '2022年03月09日',
#   '收款人': '胡颖',
#   '复核人': '董娟',
#   '价税合计（大写）': '叁佰圆整',
#   '（小写）': '无'},
#  'fp_59': {'票据代码': '无',
#   '票据号码': '1029593',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜李',
#   '复核人': '无',
#   '价税合计（大写）': '贰仟圆整',
#   '（小写）': '无'},
#  'fp_60': {'票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜李',
#   '复核人': '茜',
#   '价税合计（大写）': '贰佰圆整',
#   '（小写）': '200.00'},
#  'fp_61': {'票据代码': '102959110021311029592',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月18日',
#   '收款人': '李茜李',
#   '复核人': '无',
#   '价税合计（大写）': '无',
#   '（小写）': '200.00'},
#  'fp_62': {'票据代码': '0194934',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月17日',
#   '收款人': '张瑞建',
#   '复核人': '王娜',
#   '价税合计（大写）': '叁仟捌佰圆整',
#   '（小写）': '3800.00'},
#  'fp_63': {'票据代码': '310021317629795',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月09日',
#   '收款人': '张焰',
#   '复核人': '张佳莹',
#   '价税合计（大写）': '柒仟捌佰贰拾圆捌角壹分（小',
#   '（小写）': '无'},
#  'fp_64': {'票据代码': '44032131',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年02月17日',
#   '收款人': '无',
#   '复核人': '黄兰惠',
#   '价税合计（大写）': '玖仟肆佰圆整',
#   '（小写）': '94.00'},
#  'fp_65': {'票据代码': '440321313037304',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年02月17日',
#   '收款人': '黄兰曾清华',
#   '复核人': '无',
#   '价税合计（大写）': '壹仟贰佰圆整',
#   '（小写）': '无'},
#  'fp_66': {'票据代码': '3760883',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '022年03月04日',
#   '收款人': '管理员',
#   '复核人': '管理员',
#   '价税合计（大写）': '贰佰肆拾玖圆整',
#   '（小写）': '无'},
#  'fp_67': {'票据代码': '01267611002111601267',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': 'D2022年03月02日',
#   '收款人': '无',
#   '复核人': '无',
#   '价税合计（大写）': '贰万贰仟肆佰圆整',
#   '（小写）': '无'},
#  'fp_68': {'票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年02月10日',
#   '收款人': '管理员',
#   '复核人': '管理员',
#   '价税合计（大写）': '无',
#   '（小写）': '8240.'},
#  'fp_69': {'票据代码': '110021',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月10日',
#   '收款人': '张娜',
#   '复核人': '葛君',
#   '价税合计（大写）': '参仟伍佰壹拾伍圆整（',
#   '（小写）': '无'},
#  'fp_70': {'票据代码': '-14041002021020210306385',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月04日',
#   '收款人': '邢',
#   '复核人': '刘坤',
#   '价税合计（大写）': '陆万叁仟贰佰捌拾柴圆叁角叁分（小',
#   '（小写）': '无'},
#  'fp_71': {'票据代码': '030638410020210306385',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月04日',
#   '收款人': '无',
#   '复核人': '刘坤',
#   '价税合计（大写）': '壹万肆仟陆佰捌拾伍圆玖角捌分（小写',
#   '（小写）': '无'},
#  'fp_72': {'票据代码': '370022110578251',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月11日',
#   '收款人': '宋晓',
#   '复核人': '潘亮',
#   '价税合计（大写）': '伍仟佰圆整',
#   '（小写）': '5200.00'},
#  'fp_73': {'票据代码': '080',
#   '票据号码': '8803',
#   '校验码': '无',
#   '开票日期': '2022年03月14日',
#   '收款人': '朱海燕',
#   '复核人': '无',
#   '价税合计（大写）': '陆万柒仟捌佰玖拾陆圆叁角捌分',
#   '（小写）': '67896.38'},
#  'fp_74': {'票据代码': '11002141',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月14',
#   '收款人': '朱海燕',
#   '复核人': '李颖',
#   '价税合计（大写）': '壹拾万圆整',
#   '（小写）': '00.00'},
#  'fp_75': {'票据代码': 'in310021111289038',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2021年06月08日',
#   '收款人': '无',
#   '复核人': '许莉',
#   '价税合计（大写）': '壹仟壹佰叁拾陆圆肆角叁分',
#   '（小写）': '无'},
#  'fp_76': {'票据代码': '12869911002141',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月02日',
#   '收款人': '无',
#   '复核人': '傅铃铃',
#   '价税合计（大写）': '柒仟零陆圆整',
#   '（小写）': '无'},
#  'fp_77': {'票据代码': '21210130746',
#   '票据号码': '98',
#   '校验码': '无',
#   '开票日期': '无',
#   '收款人': '无',
#   '复核人': '高杨',
#   '价税合计（大写）': '拾圆整',
#   '（小写）': '无'},
#  'fp_78': {'票据代码': '49021002141',
#   '票据号码': '无',
#   '校验码': '0021410204907',
#   '开票日期': '2022年02月28日',
#   '收款人': '无',
#   '复核人': '无',
#   '价税合计（大写）': '捌仟伍佰参拾贰圆壹角壹分',
#   '（小写）': '无'},
#  'fp_79': {'票据代码': '50002211',
#   '票据号码': '0026746',
#   '校验码': '无',
#   '开票日期': '2022年02月25日',
#   '收款人': '彭诗洁',
#   '复核人': '李洁',
#   '价税合计（大写）': '壹佰伍拾圆整',
#   '（小写）': '150.00'},
#  'fp_80': {'票据代码': '无',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月08日',
#   '收款人': '贺云',
#   '复核人': '葛鑫',
#   '价税合计（大写）': '贰仟肆佰玖拾陆圆整',
#   '（小写）': '2496.00'},
#  'fp_81': {'票据代码': '31733',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月05日',
#   '收款人': '贺',
#   '复核人': '张静',
#   '价税合计（大写）': '无',
#   '（小写）': '无'},
#  'fp_82': {'票据代码': '72420110021317242019',
#   '票据号码': '无',
#   '校验码': '0355453543632218873',
#   '开票日期': '2022年03月02日',
#   '收款人': '陆莹',
#   '复核人': '冯淑均',
#   '价税合计（大写）': '捌佰伍拾圆整（',
#   '（小写）': '850.00'},
#  'fp_83': {'票据代码': '31002141085038',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月02日',
#   '收款人': '夏翎丰',
#   '复核人': '王蕾',
#   '价税合计（大写）': '伍佰柒拾叁圆整',
#   '（小写）': '573.00'},
#  'fp_84': {'票据代码': '12',
#   '票据号码': '无',
#   '校验码': '无',
#   '开票日期': '2022年03月11日',
#   '收款人': '林雪华',
#   '复核人': '李华琼',
#   '价税合计（大写）': '纤玖佰捌拾玖圆整',
#   '（小写）': '5989.00'},
#  'fp_85': {'票据代码': '0110020008',
#   '票据号码': '074136',
#   '校验码': '835812154819158',
#   '开票日期': '2022年01月04日',
#   '收款人': '续斌斌',
#   '复核人': '王秀娟',
#   '价税合计（大写）': '壹佰零肆圆整',
#   '（小写）': '无'},
#  'fp_86': {'票据代码': '0110020008',
#   '票据号码': '无',
#   '校验码': '651795946830239',
#   '开票日期': '2022年01月04日',
#   '收款人': '续斌斌',
#   '复核人': '王秀娟',
#   '价税合计（大写）': '贰佰贰拾陆圆肆角（',
#   '（小写）': '无'},
#  'fp_87': {'票据代码': '0110021004',
#   '票据号码': '无',
#   '校验码': '834706882201538',
#   '开票日期': '2021年12月11日',
#   '收款人': '志',
#   '复核人': '香婉',
#   '价税合计（大写）': '肆拾柒圆整',
#   '（小写）': '无'},
#  'fp_88': {'票据代码': '0110021004',
#   '票据号码': '无',
#   '校验码': '682146611534422',
#   '开票日期': '2022年01月02日',
#   '收款人': '无',
#   '复核人': '无',
#   '价税合计（大写）': '肆拾捌圆捌角玖分(小',
#   '（小写）': '无'},
#  'fp_89': {'票据代码': '0130020004',
#   '票据号码': '901171',
#   '校验码': '843392031719404',
#   '开票日期': '2021年12月02日',
#   '收款人': '范红月',
#   '复核人': '苏瑞肖',
#   '价税合计（大写）': '肆佰圆整',
#   '（小写）': '400.00'},
#  'fp_90': {'票据代码': '0110021005',
#   '票据号码': '484641',
#   '校验码': '087814981036833',
#   '开票日期': '2022年03月10日',
#   '收款人': '无',
#   '复核人': '马春晓',
#   '价税合计（大写）': '柒拾参圆捌角陆分（小写',
#   '（小写）': '无'},
#  'fp_91': {'票据代码': '0110021004',
#   '票据号码': '无',
#   '校验码': '491184515802723',
#   '开票日期': '2022年01月13日',
#   '收款人': '志',
#   '复核人': '无',
#   '价税合计（大写）': '肆拾伍圆整',
#   '（小写）': '无'},
#  'fp_92': {'票据代码': '0110020008',
#   '票据号码': '无',
#   '校验码': '535018974612667',
#   '开票日期': '2022年03月08日',
#   '收款人': '续斌斌',
#   '复核人': '王秀娟',
#   '价税合计（大写）': '壹佰伍拾圆整',
#   '（小写）': '00'},
#  'fp_93': {'票据代码': '0110020008',
#   '票据号码': '036583',
#   '校验码': '790421547432262',
#   '开票日期': '2022年03月29日',
#   '收款人': '续斌斌',
#   '复核人': '王秀娟',
#   '价税合计（大写）': '壹佰贰拾伍圆贰角(',
#   '（小写）': '无'},
#  'fp_94': {'票据代码': '0110020008',
#   '票据号码': '无',
#   '校验码': '506043918115427',
#   '开票日期': '2022年03月08日',
#   '收款人': '续斌斌',
#   '复核人': '王秀娟',
#   '价税合计（大写）': '肆拾叁圆肆角(小',
#   '（小写）': '无'},
#  'fp_95': {'票据代码': '0110021007',
#   '票据号码': '395141',
#   '校验码': '548761599220450',
#   '开票日期': '2022年03月29日',
#   '收款人': '姜晓娅',
#   '复核人': '张连霞',
#   '价税合计（大写）': '壹佰柒拾伍圆伍角（小',
#   '（小写）': '无'},
#  'fp_96': {'票据代码': '01100210021',
#   '票据号码': '无',
#   '校验码': '706174754312589',
#   '开票日期': '2022年03月08日',
#   '收款人': '无',
#   '复核人': '刘晓开',
#   '价税合计（大写）': '壹佰圆零陆角(小',
#   '（小写）': '100.60'},
#  'fp_97': {'票据代码': '0110020008',
#   '票据号码': '无',
#   '校验码': '596079334729780',
#   '开票日期': '2022年01月04日',
#   '收款人': '续斌斌',
#   '复核人': '王秀娟',
#   '价税合计（大写）': '陆拾陆圆叁角',
#   '（小写）': '无'},
#  'fp_98': {'票据代码': '0110020008',
#   '票据号码': '无',
#   '校验码': '513305342719049',
#   '开票日期': '2022年01月04日',
#   '收款人': '续斌斌',
#   '复核人': '王秀娟',
#   '价税合计（大写）': '伍圆整',
#   '（小写）': '.00'},
#  'fp_99': {'票据代码': '0110021005',
#   '票据号码': '431365',
#   '校验码': '061535864719672',
#   '开票日期': '2022年01月04日',
#   '收款人': '雪丽',
#   '复核人': '赵笑林',
#   '价税合计（大写）': '陆拾捌圆陆角玖分',
#   '（小写）': '无'}}

# %%
for key,value in result.items():
    insertcsv('datasets/onlyBert.csv',key,value)
